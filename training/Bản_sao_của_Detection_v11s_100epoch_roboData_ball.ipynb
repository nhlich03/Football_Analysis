# %%
# !pip install ultralytics
# !pip install roboflow
# !pip install wandb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 903.1/903.1 kB 35.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from roboflow import Roboflow

'''
rf = Roboflow(api_key="cHei9gvcHM5yhX40sx9a") # THIS API KEY IS REVOKED. PLEASE USE YOUR OWN API KEY
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
'''
'''
rf = Roboflow(api_key="foYmYp1nEeMQN3vmWhhU")
project = rf.workspace("label-gdoal").project("soccer-oilql")
version = project.version(2)
dataset = version.download("yolov5")
'''

'''
rf = Roboflow(api_key="foYmYp1nEeMQN3vmWhhU")
project = rf.workspace("mihailo").project("football-players-detection-3zvbc-7ocfe")
version = project.version(2)
dataset = version.download("yolov11")
'''

rf = Roboflow(api_key="foYmYp1nEeMQN3vmWhhU")
project = rf.workspace("roboflow-jvuqo").project("football-ball-detection-rejhg")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-ball-detection-2 in yolov8:: 100%|██████████| 4434/4434 [00:02<00:00, 2093.21it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
dataset.location
# Out:
# '/content/football-ball-detection-2'

# %%
'''import shutil

shutil.move('football-players-detection-2/train',
            'football-players-detection-2/football-players-detection-2/train'
            )

shutil.move('football-players-detection-2/test',
            'football-players-detection-2/football-players-detection-2/test'
            )

shutil.move('football-players-detection-2/valid',
            'football-players-detection-2/football-players-detection-2/valid'
            )
            '''
# Out:
# "import shutil\n\nshutil.move('football-players-detection-2/train',\n            'football-players-detection-2/football-players-detection-2/train'\n            )\n\nshutil.move('football-players-detection-2/test',\n            'football-players-detection-2/football-players-detection-2/test'\n            )\n\nshutil.move('football-players-detection-2/valid',\n            'football-players-detection-2/football-players-detection-2/valid'\n            )\n            "

# %%
import wandb
wandb.login(key='4123b9360afdc94c1dd57892d4a5887bda7fa8e7')
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: lichhoanglich987 (hcmus-nguyenhoanglich). Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
from ultralytics import YOLO
model = YOLO("yolo11s.pt")
train_model = model.train(data="/content/football-ball-detection-2/data.yaml", epochs=50, patience=5, imgsz=1280, batch=8, plots=True)
# Out:
# ...
# 100%|██████████| 18.4M/18.4M [00:00<00:00, 123MB/s]
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
metrics = model.val()
metrics.box.map
metrics.box.map50
metrics.box.map75
metrics.box.maps
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /content/football-ball-detection-2/valid/labels.cache... 121 images, 0 backgrounds, 0 corrupt: 100%|██████████| 121/121 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:04<00:00,  3.43it/s]
#                    all        121        121      0.979       0.76      0.894      0.552
# Speed: 0.8ms preprocess, 22.3ms inference, 0.0ms loss, 3.8ms postprocess per image
# Results saved to runs/detect/train2
# array([    0.55182])

# %%
import pandas as pd

# Đường dẫn tới file results.csv
csv_path = "/content/runs/detect/train/results.csv"

# Đọc file CSV
df = pd.read_csv(csv_path)

df
# Out:
#     epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0       1   182.299         2.23417        35.89040         0.85734
# 1       2   354.149         2.17912         1.60284         0.86403
# 2       3   525.798         2.08238         1.40833         0.85503
# 3       4   695.961         2.04188         1.26361         0.85331
# 4       5   866.354         1.95658         1.26629         0.84435
# 5       6  1036.710         1.88116         1.18494         0.83859
# 6       7  1204.900         1.84377         1.12438         0.83287
# 7       8  1376.270         1.74110         1.12038         0.81979
# 8       9  1546.050         1.68397         1.06241         0.82473
# 9      10  1715.280         1.76780         1.01510         0.82629
# 10     11  1886.190         1.69081         1.01213         0.81678
# 11     12  2055.770         1.67297         1.00595         0.82173
# 12     13  2225.700         1.69926         0.95782         0.82177
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Vẽ Loss trong quá trình Train và Validation
plt.figure(figsize=(12, 6))
plt.plot(df['epoch'], df['train/box_loss'], label='Train Box Loss', color='red', linestyle='--')
plt.plot(df['epoch'], df['train/cls_loss'], label='Train Cls Loss', color='blue', linestyle='--')
plt.plot(df['epoch'], df['train/dfl_loss'], label='Train DFL Loss', color='green', linestyle='--')
plt.plot(df['epoch'], df['val/box_loss'], label='Val Box Loss', color='red')
plt.plot(df['epoch'], df['val/cls_loss'], label='Val Cls Loss', color='blue')
plt.plot(df['epoch'], df['val/dfl_loss'], label='Val DFL Loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.grid()
plt.show()

# %%
import shutil

# Đường dẫn đến mô hình đã huấn luyện
trained_model_path = "/content/runs/detect/train/weights/best.pt"  # Hoặc "last.pt"

# Đường dẫn lưu trên Google Drive
save_path = "/content/drive/MyDrive/best_yolov11s_model_roboData_ball.pt"  # Đặt tên file theo ý bạn

# Sao chép file mô hình vào Google Drive
shutil.copy(trained_model_path, save_path)

print(f"Model đã được lưu vào Google Drive tại: {save_path}")
# Out:
# Model đã được lưu vào Google Drive tại: /content/drive/MyDrive/best_yolov11s_model_roboData_ball.pt

# %%
from ultralytics import YOLO

# Tải mô hình đã lưu
model = YOLO("/content/drive/MyDrive/best_yolov11s_model_roboData_ball.pt")  # Đường dẫn tới file .pt

# %%
# Dự đoán trên ảnh
results = model.predict(source="/content/drive/MyDrive/000422.jpg", save = True) # Đường dẫn ảnh
# Out:
# image 1/1 /content/drive/MyDrive/000422.jpg: 736x1280 1 ball, 49.5ms
# Speed: 7.5ms preprocess, 49.5ms inference, 1.5ms postprocess per image at shape (1, 3, 736, 1280)
# Results saved to runs/detect/predict

# %%
import cv2
from matplotlib import pyplot as plt

# Đọc ảnh đã dự đoán
predicted_image_path = "/content/runs/detect/predict/000422.jpg"  # Đường dẫn ảnh đã dự đoán
img = cv2.imread(predicted_image_path)

# Hiển thị ảnh
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# Hiển thị ảnh
img_url = "/content/drive/MyDrive/000422.jpg"
img = cv2.imread(img_url)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
results = model.predict(source="/content/drive/MyDrive/Seminar/Video/test_30s.avi", save_txt=True, save_conf=True, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/900) /content/drive/MyDrive/Seminar/Video/test_30s.avi: 736x1280 2 balls, 29.9ms
# video 1/1 (frame 2/900) /content/drive/MyDrive/Seminar/Video/test_30s.avi: 736x1280 3 balls, 29.8ms
# video 1/1 (frame 3/900) /content/drive/MyDrive/Seminar/Video/test_30s.avi: 736x1280 4 balls, 29.8ms
# video 1/1 (frame 4/900) /content/drive/MyDrive/Seminar/Video/test_30s.avi: 736x1280 2 balls, 29.8ms
# ...

# %%
import shutil

video_path = "/content/runs/detect/predict/test_30s.avi"
output_dir = "/content/drive/MyDrive/Seminar/"

shutil.move(video_path, output_dir)
# Out:
# '/content/drive/MyDrive/Seminar/test_30s.avi'
